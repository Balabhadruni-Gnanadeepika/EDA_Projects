# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\HOME\GnanaDeepika\Python\IMDb_Dataset.csv")

# %%
data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
data.tail()
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                     Star Cast  \
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 396         Tim Burton    Alfred GoughMiles MillarSeth Grahame-Smith
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 398     John Krasinski     Cailey FlemingRyan ReynoldsJohn Krasinski
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  Duration (minutes)
# 395       39.0                88.0
# 396       66.9               116.3
# ...

# %%
data.shape
# Out:
# (400, 9)

# %%
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
data.isna().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Title                 False
# IMDb Rating           False
# Year                  False
# Certificates          False
# Genre                 False
# Director              False
# Star Cast             False
# MetaScore             False
# Duration (minutes)    False
# dtype: bool

# %%
data['Genre']
# Out:
# 0         Action
# 1         Action
# 2         Action
# 3      Adventure
# 4         Action
#          ...
# 395       Comedy
# 396       Comedy
# 397       Comedy
# 398    Animation
# 399       Action
# Name: Genre, Length: 400, dtype: object

# %%
data[['Title','IMDb Rating','Year']].head(20)
# Out:
#                                                 Title  IMDb Rating  Year
# 0                                           Gladiator          8.5  2000
# 1       Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2                Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                                Inglourious Basterds          8.4  2009
# 4                                         Borderlands          7.1  2024
# 5                                       Jurassic Park          8.2  1993
# 6                                   The Fifth Element          7.6  1997
# 7                                          Inside Out          8.1  2015
# 8                        Descendants: The Rise of Red          7.1  2024
# 9                                                Wish          5.6  2023
# 10                                   The Hunger Games          7.2  2012
# 11             Rebel Moon - Part One: A Child of Fire          5.6  2023
# ...

# %%
data['IMDb Rating'].head(20)>= 7.0
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# Name: IMDb Rating, dtype: bool

# %%
dt = data['IMDb Rating'].head(400)
c=0
for i in dt:
    if i >= 7.0:
        c+=1
print(c)
# Out:
# 265

# %%
data.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
A=data['Duration (minutes)'].value_counts()
print(A)
print("------------------------------------------------------")
GS=data['MetaScore'].value_counts()
print(GS)
print("------------------------------------------------------")
data['IMDb Rating'].value_counts()
# Out:
# Duration (minutes)
# 116.3    53
# 115.0    16
# 105.0    13
# 92.0     13
# 95.0     13
#          ..
# 206.0     1
# 176.0     1
# 163.0     1
# 106.0     1
# 81.0      1
# Name: count, Length: 79, dtype: int64
# ------------------------------------------------------
# MetaScore
# 66.9     65
# 73.0     12
# 47.0     12
# 74.0     12
# 46.0     11
#          ..
# 27.0      1
# 97.0      1
# 36.0      1
# 100.0     1
# 42.0      1
# Name: count, Length: 66, dtype: int64
# ------------------------------------------------------
# IMDb Rating
# 7.1    59
# 7.0    24
# 7.6    21
# 6.7    18
# 7.2    16
# 6.8    16
# 7.4    14
# 8.0    13
# 7.9    13
# 7.5    13
# 8.1    12
# 8.2    12
# 7.3    11
# 6.5    11
# 5.6    10
# 6.2    10
# 5.7    10
# 8.4    10
# 8.6     9
# 6.3     9
# 7.7     8
# 7.8     8
# 8.5     8
# 6.1     6
# 5.8     5
# 5.9     5
# 6.9     5
# 6.0     5
# 8.7     4
# 5.5     4
# 6.4     4
# 5.0     4
# 3.9     3
# 8.3     3
# 5.2     3
# 5.3     2
# 9.0     2
# ...

# %%
data[data.index.isin(range(2,20))]
# Out:
#                                                 Title  IMDb Rating  Year  \
# 2                Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                                Inglourious Basterds          8.4  2009
# 4                                         Borderlands          7.1  2024
# 5                                       Jurassic Park          8.2  1993
# 6                                   The Fifth Element          7.6  1997
# 7                                          Inside Out          8.1  2015
# 8                        Descendants: The Rise of Red          7.1  2024
# 9                                                Wish          5.6  2023
# 10                                   The Hunger Games          7.2  2012
# 11             Rebel Moon - Part One: A Child of Fire          5.6  2023
# 12              Harry Potter and the Sorcerer's Stone          7.6  2001
# 13                                              Wonka          7.0  2023
# ...

# %%
dt=data[data.index.isin(range(2,5))]
dt1=dt.loc[dt['IMDb Rating']>= 7.0]
sns.barplot(data=dt1 ,y='IMDb Rating',x='Title')
# Out:
# <Axes: xlabel='Title', ylabel='IMDb Rating'>

# %%
dt=data[data.index.isin(range(5,10))]
data2=dt.loc[dt['Year']>= 1999]
sns.barplot(data=data2 ,x='Title',y='Year')
# Out:
# <Axes: xlabel='Title', ylabel='Year'>

# %%
dt=data[data.index.isin(range(2,400))]
d2=dt.loc[dt['Duration (minutes)']>=150.00]
sns.lineplot(data=d2 ,x='IMDb Rating',y='Duration (minutes)')
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='IMDb Rating', ylabel='Duration (minutes)'>

# %%
data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
dt= data.head(50)
dt4=dt[(dt['IMDb Rating']>= 7.0)&(dt['MetaScore']>=50.0)]
sns.lineplot(x='IMDb Rating' ,y='MetaScore',data=dt4)
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='IMDb Rating', ylabel='MetaScore'>

# %%
dt=data[data.index.isin(range(2,100))]
d2=dt.loc[dt['Year']>2000]
sns.lineplot(data=d2 ,x='Genre',y='Year')
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Genre', ylabel='Year'>

# %%
dt=data[data.index.isin(range(2,10))]
sns.countplot(x='Certificates', data=dt)
# Out:
# <Axes: xlabel='Certificates', ylabel='count'>

# %%
dt= data.head(20)
dt2=dt[dt['Certificates']>='R']
sns.stripplot(x='Director' ,y='Certificates',data=dt2)
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Director', ylabel='Certificates'>

# %%
dt= data.head(20)
dt2=dt[dt['IMDb Rating']>=8.0]
sns.stripplot(x='IMDb Rating' ,y='Star Cast',data=dt2)
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='IMDb Rating', ylabel='Star Cast'>

# %%
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
dt=data.head(20)
sns.pairplot(dt[['IMDb Rating','Year','MetaScore']])
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt

# Filter the data
#dt = data.head(20)
year_data = data['Year'].head(10)
Genre_data = data['Genre'].head(10)

# Plotting the pie chart
plt.pie(year_data, labels=Genre_data, autopct='%1.1f%%', startangle=140)
plt.title("Pie chart for year and Genre	")
plt.show()
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
labels = data['Certificates'].head(5)
sizes= data['Duration (minutes)'].head(5)
plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Pie chart For Duration (minutes) and Certificates")
plt.show()

# %%
data.head(10)
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
# 5                                  Jurassic Park          8.2  1993
# 6                              The Fifth Element          7.6  1997
# 7                                     Inside Out          8.1  2015
# 8                   Descendants: The Rise of Red          7.1  2024
# 9                                           Wish          5.6  2023
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# ...

# %%
dt=data[data.index.isin(range(2,100))]
MS = dt['MetaScore'].head(3)
T = dt['Title'].head(3)

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(MS, T)
plt.subplot(133)
plt.scatter(MS, T)
#plt.subplot(133)
#plt.plot(SC, T)
plt.suptitle('Categorical Plotting btw Star Cast and Title')
plt.show()
