# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\HOME\GnanaDeepika\Python\customer_purchase_data.csv")

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
data.tail()
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1495           34.590743               0                 5               1
# 1496           17.625707               0                 1               1
# 1497           12.206033               0                 0               0
# 1498           37.311634               1                 0               1
# 1499           25.348017               1                 4               1

# %%
data.shape
# Out:
# (1500, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
data.isna().sum()
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Age                   False
# Gender                False
# AnnualIncome          False
# NumberOfPurchases     False
# ProductCategory       False
# TimeSpentOnWebsite    False
# LoyaltyProgram        False
# DiscountsAvailed      False
# PurchaseStatus        False
# dtype: bool

# %%
data['NumberOfPurchases']
# Out:
# 0        8
# 1        4
# 2       11
# 3       19
# 4       19
#         ..
# 1495    13
# 1496    18
# 1497     7
# 1498    16
# 1499    13
# Name: NumberOfPurchases, Length: 1500, dtype: int64

# %%
data['Age'].head(20)
# Out:
# 0     40
# 1     20
# 2     27
# 3     24
# 4     31
# 5     66
# 6     39
# 7     64
# 8     43
# 9     20
# 10    66
# 11    70
# 12    54
# 13    64
# 14    19
# 15    70
# 16    51
# 17    18
# 18    57
# 19    20
# Name: Age, dtype: int64

# %%
data[['Age','Gender']].head(20)
# Out:
#     Age  Gender
# 0    40       1
# 1    20       1
# 2    27       1
# 3    24       1
# 4    31       1
# 5    66       1
# 6    39       1
# 7    64       1
# 8    43       0
# 9    20       1
# 10   66       1
# 11   70       1
# 12   54       0
# 13   64       1
# 14   19       1
# 15   70       1
# 16   51       1
# 17   18       1
# 18   57       0
# 19   20       0

# %%
data['Age'].head(20)>= 40
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17    False
# 18     True
# 19    False
# Name: Age, dtype: bool

# %%
dt = data['Age']
c=0
for i in dt:
    if i >= 70:
        c+=1
print(c)
# Out:
# 30

# %%
dt = data['Age']
c=0
for i in dt:
    if i >= 60:
        c+=1
print(c)
# Out:
# 328

# %%
df=data.head(1500)
df.sort_index(ascending=False).head()
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1499   50       0   52625.665974                 13                0
# 1498   63       0  134021.775532                 16                2
# 1497   40       1   57363.247541                  7                4
# 1496   67       1   28775.331069                 18                2
# 1495   39       1   65048.141834                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1499           25.348017               1                 4               1
# 1498           37.311634               1                 0               1
# 1497           12.206033               0                 0               0
# 1496           17.625707               0                 1               1
# 1495           34.590743               0                 5               1

# %%
Sorting = data[data['NumberOfPurchases']>15].sort_values(by='TimeSpentOnWebsite',ascending=False).head()
Sorting
# Out:
#      Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 616   29       1   58153.547017                 16                2
# 209   42       0   42778.830374                 17                3
# 328   46       0   50866.350889                 19                0
# 833   63       0   76497.474912                 17                0
# 655   65       0  143121.786724                 19                2
#
#      TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 616           59.991105               1                 3               1
# 209           59.985342               0                 3               0
# 328           59.741525               1                 0               1
# 833           59.621112               0                 1               0
# 655           59.532411               0                 2               0

# %%
data1=data[data["Age"]>=70]
data1.sort_index(ascending=True).head()
# Out:
#      Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 11    70       1   83556.718133                 11                2
# 15    70       1   67049.598809                  2                4
# 71    70       0  119425.274117                  4                3
# 89    70       0   85814.587734                 19                0
# 111   70       1   59135.990118                  5                3
#
#      TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 11            42.173999               0                 4               1
# 15            21.895098               0                 0               0
# 71            45.355881               0                 5               0
# 89            13.078448               1                 0               0
# 111           18.858073               0                 0               1

# %%
data.describe()
# Out:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
AI=data['AnnualIncome'].value_counts()
print(AI)
print("------------------------------------------------------")
NOP=data['NumberOfPurchases'].value_counts()
print(NOP)
print("------------------------------------------------------")
data['TimeSpentOnWebsite'].value_counts()
# Out:
# AnnualIncome
# 21213.110578     2
# 38456.358669     2
# 24590.476142     2
# 31518.055858     2
# 61286.283384     2
#                 ..
# 41574.136388     1
# 112813.842226    1
# 131245.843658    1
# 138026.843191    1
# 52625.665974     1
# Name: count, Length: 1388, dtype: int64
# ------------------------------------------------------
# NumberOfPurchases
# 14    88
# 10    87
# 12    84
# 15    83
# 19    81
# 16    81
# 11    78
# 3     75
# 7     73
# 13    73
# 18    70
# 9     70
# 5     68
# 20    67
# 2     65
# 6     64
# 4     64
# 17    63
# 1     62
# 8     53
# 0     51
# Name: count, dtype: int64
# ------------------------------------------------------
# TimeSpentOnWebsite
# 18.673823    2
# 51.337373    2
# 14.971058    2
# 54.702783    2
# 15.054357    2
#             ..
# 31.732049    1
# 45.227243    1
# 43.837618    1
# 48.379192    1
# 25.348017    1
# Name: count, Length: 1388, dtype: int64

# %%
data[data.index.isin(range(10,20))]
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 10   66       1   66199.993929                 11                1
# 11   70       1   83556.718133                 11                2
# 12   54       0  114467.228969                  9                2
# 13   64       1   31880.893223                 17                0
# 14   19       1  107485.660911                  7                1
# 15   70       1   67049.598809                  2                4
# 16   51       1  129174.208866                 13                4
# 17   18       1  128374.495052                  0                2
# 18   57       0   71740.688084                 12                2
# 19   20       0  121499.006189                 12                3
#
#     TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 10            1.415532               1                 5               1
# 11           42.173999               0                 4               1
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
dt=data[data.index.isin(range(2,200))]
dt1=dt.loc[dt['Age']>=50]
sns.barplot(data=dt1 ,x='NumberOfPurchases',y='Age')
# Out:
# <Axes: xlabel='NumberOfPurchases', ylabel='Age'>

# %%
dt=data[data.index.isin(range(2,20))]
data2=dt.loc[dt['AnnualIncome']>=25000.00]
sns.barplot(data=data2 ,x='NumberOfPurchases',y='AnnualIncome')
# Out:
# <Axes: xlabel='NumberOfPurchases', ylabel='AnnualIncome'>

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
dt=data[data.index.isin(range(2,100))]
d2=dt.loc[dt['AnnualIncome']>=15000.00]
sns.lineplot(data=d2 ,x='ProductCategory',y='AnnualIncome')
# Out:
# <Axes: xlabel='ProductCategory', ylabel='AnnualIncome'>

# %%
data[data.index.isin(range(1,200))]
# Out:
#      Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1     20       1   23579.773583                  4                2
# 2     27       1  127821.306432                 11                2
# 3     24       1  137798.623120                 19                3
# 4     31       1   99300.964220                 19                1
# 5     66       1   37758.117475                 14                4
# ..   ...     ...            ...                ...              ...
# 195   22       0  147050.028039                  2                0
# 196   50       0   81923.645329                  5                0
# 197   27       0  120479.792644                 19                2
# 198   43       1  147283.641942                 12                0
# 199   22       0   87622.086000                  2                1
#
#      TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1             38.240097               0                 5               0
# ...

# %%
dt4=data[(data['Age']>50)&(data['TimeSpentOnWebsite']>=30.00)]
sns.lineplot(x='Age' ,y='TimeSpentOnWebsite',data=dt4)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSpentOnWebsite'>

# %%
dt=data[data.index.isin(range(2,100))]
d2=dt.loc[dt['TimeSpentOnWebsite']>=15.00]
sns.lineplot(data=d2 ,x='NumberOfPurchases',y='TimeSpentOnWebsite')
# Out:
# <Axes: xlabel='NumberOfPurchases', ylabel='TimeSpentOnWebsite'>

# %%
dt=data[data.index.isin(range(2,20))]
sns.countplot(x='Age', data=dt)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
dt2=data[data['Age']>=60]
sns.stripplot(x='PurchaseStatus' ,y='Age',data=dt2)
# Out:
# <Axes: xlabel='PurchaseStatus', ylabel='Age'>

# %%
dt3=data[(data['NumberOfPurchases']>15)&(data['AnnualIncome']>=100000.00)]
sns.stripplot(x='NumberOfPurchases' ,y='AnnualIncome',data=dt3)
# Out:
# <Axes: xlabel='NumberOfPurchases', ylabel='AnnualIncome'>

# %%
data.head(10)
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
# 5   66       1   37758.117475                 14                4
# 6   39       1  126883.385286                 16                3
# 7   64       1   39707.359724                 13                2
# 8   43       0  102797.301269                 20                1
# 9   20       1   63854.921080                 16                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# ...

# %%
import matplotlib.pyplot as plt

# Filter the data
dt = data.head(20)
Age_data = dt.loc[dt['Age'] > 50, 'Age']
NOP_data = dt.loc[dt['Age'] > 50, 'NumberOfPurchases']

# Plotting the pie chart
plt.pie(NOP_data, labels=Age_data, autopct='%1.1f%%', startangle=140)
plt.title("Pie chart for age and NumberOfPurchases	")
plt.show()

# %%
import matplotlib.pyplot as plt
labels = data['Age'].head(5)
sizes= data['ProductCategory'].head(5)
plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Pie chart For Age and ProductCategory")
plt.show()

# %%
Age_data=data['Age'].head(20)
NOP = data['ProductCategory'].head(20)
index= data['NumberOfPurchases'].head()
df = pd.DataFrame({'Age':Age_data,'ProductCategory': NOP }, index=index)
plot = df.plot.pie(y='Age', figsize=(5, 5))

# %%
plot = df.plot.pie(subplots=True, figsize=(11, 6))

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
dt=data[data.index.isin(range(2,50))]
NOP = dt['NumberOfPurchases'].head(5)
DA = dt['DiscountsAvailed'].head(5)

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(NOP, DA)
plt.subplot(132)
plt.scatter(NOP, DA)
plt.subplot(133)
plt.plot(NOP, DA)
plt.suptitle('Categorical Plotting btw NumberOfPurchases and DiscountsAvailed')
plt.show()

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
sns.pairplot(data[['Age','AnnualIncome','NumberOfPurchases','ProductCategory','TimeSpentOnWebsite']])

# %%
dt=data.head()
g = sns.FacetGrid(dt, col="Age", hue="NumberOfPurchases")
g.map(sns.scatterplot, "Age", "NumberOfPurchases", alpha=.7)
g.add_legend()

# %%
dt= data.head(3)
g = sns.FacetGrid(dt, col="AnnualIncome")
g.map(sns.histplot, "ProductCategory")

# %%
data4=data.head(200)
sns.displot(data4['Age'])

# %%
dt=data.head(20)
def rel_x_y(dt,x,y):
    sns.jointplot(data=dt,x=x,y=y,hue='ProductCategory')
    plt.show()
rel_x_y(dt, 'Age', 'ProductCategory')

# %%
Top_batsman = data[data['Age']>=70].sort_values(by='Age',ascending=False).head(10)
print(Top_batsman)
rel_x_y(Top_batsman, 'Age', 'PurchaseStatus')
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 11     70       1   83556.718133                 11                2
# 15     70       1   67049.598809                  2                4
# 1448   70       0   89340.261739                  7                2
# 1433   70       0  131563.016910                  5                3
# 1401   70       1  144468.242475                 11                4
# 1260   70       1  106116.421521                  1                0
# 1211   70       0   29828.655280                 14                3
# 1198   70       1   59690.387971                  2                0
# 1179   70       1   77257.375541                  7                3
# 1100   70       1   52791.332623                  1                1
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 11             42.173999               0                 4               1
# ...

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
# Import the necessary modules 
import matplotlib.pyplot as plt 
import pandas as pd 


# Initialize the lists for X and Y 
data = pd.read_csv(r"C:\Users\HOME\GnanaDeepika\Python\customer_purchase_data.csv") 

df= data.head()

X = list(df.iloc[:, 0])
print(X)
Y = list(df.iloc[:, 3])
print(Y)

# Plot the data using bar() method 
plt.bar(X, Y, color='b',) 
plt.title("Number Of Purchases By Age vise") 
plt.xlabel("Age") 
plt.ylabel("Number of Purchases") 

# Show the plot 
plt.show()
# Out:
# [40, 20, 27, 24, 31]
# [8, 4, 11, 19, 19]

# %%
import pandas as pd
Age_data=data['Age'].head(200)
DA_data=data['DiscountsAvailed'].head(200)
index = data['Age'].head()	
df = pd.DataFrame({'Age': Age_data,
                   'DiscountsAvailed': DA_data}, index=index)
ax = df.plot.bar(rot=0)

# %%
Age_data=data['Age'].head(20)
NOP = data['ProductCategory'].head(20)
index= data['NumberOfPurchases'].head()
df = pd.DataFrame({'Age':Age_data,'ProductCategory': NOP }, index=index)
lines = df.plot.line()

# %%
axes = df.plot.line(subplots=True)
type(axes)
# Out:
# numpy.ndarray
